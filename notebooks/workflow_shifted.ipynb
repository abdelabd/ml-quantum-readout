# %%
import os 
import sys 
sys.path.append("../training")
import pickle
import copy
import time

import hls4ml 
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.metrics import accuracy_score, auc, roc_curve

import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, BatchNormalization, Dropout
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.losses import CategoricalCrossentropy

from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning
import tensorflow_model_optimization as tfmot

from qkeras.qlayers import QDense, QActivation
from qkeras import QBatchNormalization
from qkeras.quantizers import quantized_bits, quantized_relu
from qkeras.utils import _add_supported_quantized_objects
from tensorflow.keras.models import load_model
from qkeras.utils import _add_supported_quantized_objects

# Local imports
from save_data import process_data

np.random.seed(0)
# Out:
# 2024-04-22 22:01:43.507035: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-22 22:01:43.616902: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-04-22 22:01:43.616924: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-04-22 22:01:44.102839: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-04-22 22:01:44.102914: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-04-22 22:01:44.102925: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARN: Unable to import optimizer(s) from expr_templates.py: No module named 'sympy'
# WARNING: Failed to import handlers from convolution.py: No module named 'torch'.
# WARNING: Failed to import handlers from core.py: No module named 'torch'.
# WARNING: Failed to import handlers from merge.py: No module named 'torch'.
# WARNING: Failed to import handlers from pooling.py: No module named 'torch'.
# WARNING: Failed to import handlers from reshape.py: No module named 'torch'.
# /data/aelabd/miniforge3/envs/ml4qick-env/lib/python3.8/site-packages/hls4ml/converters/__init__.py:27: UserWarning: WARNING: Pytorch converter is not enabled!
#   warnings.warn("WARNING: Pytorch converter is not enabled!", stacklevel=1)

# %% [markdown]
# ## Setup data

# %%
def one_hot_encode(data):
    y_encoded = np.zeros([data.shape[0],2], dtype=np.int32)
    for idx, x in enumerate(data):
        if x == 1:
            y_encoded[idx][1] = 1
        else:
            y_encoded[idx][0] = 1
    return y_encoded

# %%
# START_WINDOW = 285
# END_WINDOW = 385

# START_WINDOW = 150
# END_WINDOW = 350

START_WINDOW = 150
END_WINDOW = 550

# START_WINDOW = 0
# END_WINDOW = 500

# START_WINDOW = 0
# END_WINDOW = 770

# !mkdir -p models

PADDING = "zero"
MAX_SHIFT = 200 #570
INCREMENT = 20
NOISE_LO = -4
NOISE_HI = 4
RIGHT_SHIFT_STR = f"rightshift_{PADDING}padding_maxshift{MAX_SHIFT}_inc{INCREMENT}_noisem{np.abs(NOISE_LO)}p{NOISE_HI}"
LEFT_SHIFT_STR = f"leftshift_{PADDING}padding_maxshift{MAX_SHIFT}_inc{INCREMENT}_noisem{np.abs(NOISE_LO)}p{NOISE_HI}"
BOTH_SHIFT_STR = f"bothshift_{PADDING}padding_maxshift{MAX_SHIFT}_inc{INCREMENT}_noisem{np.abs(NOISE_LO)}p{NOISE_HI}"

RIGHT_DATA_LOAD_DIR = os.path.join(f'../data/qick_data/{START_WINDOW}_{END_WINDOW}_shifted', RIGHT_SHIFT_STR)
LEFT_DATA_LOAD_DIR = os.path.join(f'../data/qick_data/{START_WINDOW}_{END_WINDOW}_shifted', LEFT_SHIFT_STR)
MODEL_DIR = os.path.join(f'models/model_{START_WINDOW}_{END_WINDOW}', BOTH_SHIFT_STR)

# convert raw ADC data into npy files 
if not os.path.exists(f'{RIGHT_DATA_LOAD_DIR}/X_train.npy'):
    raise NotImplementedError("Right-shifted data does not exist, run 'make_shifted_data.ipynb'")
if not os.path.exists(f'{LEFT_DATA_LOAD_DIR}/X_train.npy'):
    raise NotImplementedError("Left-shifted data does not exist, run 'make_shifted_data.ipynb'")

# %%
tic = time.time()

# load right-data
X_train_val_r = np.load(os.path.join(RIGHT_DATA_LOAD_DIR, 'X_train.npy'))
y_train_val_r = np.load(os.path.join(RIGHT_DATA_LOAD_DIR, 'y_train.npy'))
X_test_r = np.load(os.path.join(RIGHT_DATA_LOAD_DIR, 'X_test.npy')) 
y_test_r = np.load(os.path.join(RIGHT_DATA_LOAD_DIR, 'y_test.npy'))
print("Loaded right-data")

# Drop half the right-data samples (limited memory)
right_keep_indeces = np.random.choice(range(X_train_val_r.shape[0]), size = (X_train_val_r.shape[0]//2,), replace = False)
X_train_val_r = X_train_val_r[right_keep_indeces]
y_train_val_r = y_train_val_r[right_keep_indeces]
print("Dropped half of right-data")

# load left-data
X_train_val_l = np.load(os.path.join(LEFT_DATA_LOAD_DIR, 'X_train.npy'))
y_train_val_l = np.load(os.path.join(LEFT_DATA_LOAD_DIR, 'y_train.npy'))
X_test_l = np.load(os.path.join(LEFT_DATA_LOAD_DIR, 'X_test.npy')) 
y_test_l = np.load(os.path.join(LEFT_DATA_LOAD_DIR, 'y_test.npy'))
print("Loaded left-data")

# Drop half the left-data samples (limited memory)
left_keep_indeces = np.random.choice(range(X_train_val_l.shape[0]), size = (X_train_val_l.shape[0]//2,), replace = False)
X_train_val_l = X_train_val_l[left_keep_indeces]
y_train_val_l = y_train_val_l[left_keep_indeces]
print("Dropped half of left-data")

X_train_val = np.concatenate((X_train_val_r, X_train_val_l), axis=0)
del X_train_val_r, X_train_val_l
y_train_val = np.concatenate((y_train_val_r, y_train_val_l), axis=0)
del y_train_val_r, y_train_val_l
X_test = np.concatenate((X_test_r, X_test_l), axis=0)
del X_test_r, X_test_l
y_test = np.concatenate((y_test_r, y_test_l), axis=0)
del y_test_r, y_test_l
print("Concatenated data")

tv_shuffler = np.random.permutation(range(X_train_val.shape[0]))
X_train_val = X_train_val[tv_shuffler]
y_train_val = y_train_val[tv_shuffler]

test_shuffler = np.random.permutation(range(X_test.shape[0]))
X_test = X_test[test_shuffler]
y_test = y_test[test_shuffler]
print("Shuffled data")

y_train_val = one_hot_encode(y_train_val) # 1xN binary --> 2xN one-hot-encoded
y_test = one_hot_encode(y_test)
print("Reshaped data")

print("Training:")
print("\tSize:", len(X_train_val))
print("\tSample Shape:", len(X_train_val[0]))
print("\tMean:", X_train_val.mean())
print("\tStd. Dev.:", X_train_val.std())

print("Testing:")
print("\tSize:", len(X_test))
print("\tSample Shape:", len(X_test[0]))
print("\tSample Shape:", X_test.mean())
print("\tStd. Dev.:", X_test.std())

# X_train_val[0] = I, Q timeseries over (END_WINDOW - START_WINDOW) timesteps
assert len(X_train_val[0]) == (END_WINDOW-START_WINDOW)*2, "ERROR: Specified window does not match loaded dataset shape"
assert len(X_test[0]) == (END_WINDOW-START_WINDOW)*2, "ERROR: Specified window does not match loaded dataset shape"

toc = time.time()
dur = toc - tic
print(f"Duration: {dur//60} minutes, {dur%60} seconds")
# Out:
# Loaded right-data
# Dropped half of right-data
# Loaded left-data
# Dropped half of left-data
# Concatenated data
# Shuffled data
# Reshaped data
# Training:
# 	Size: 10908000
# 	Sample Shape: 800
# 	Mean: -21.255728
# 	Std. Dev.: 1542.8718
# Testing:
# 	Size: 2424000
# 	Sample Shape: 800
# 	Sample Shape: -16.285664
# 	Std. Dev.: 1541.3585

# %% [markdown]
# ## Construct a model
# QKeras is "Quantized Keras" for deep heterogeneous quantization of ML models. We're using QDense layer instead of Dense. We're also training with model sparsity, since QKeras layers are prunable.

# %%
INIT_LEARNING_RATE = 1e-2
VALIDATION_SPLIT = 0.3
BATCH_SIZE = 12800
EPOCHS = 30
PATIENCE = 10
CHECKPOINT_FILENAME = MODEL_DIR + f'/qmodel_{START_WINDOW}_{END_WINDOW}.h5'
INPUT_SHAPE = (len(X_train_val[0]),)
print(INPUT_SHAPE)
# Out:
# (800,)

# %%
# Define model with quantize layers 
model = Sequential()
model.add(QDense(2, input_shape=INPUT_SHAPE, name='fc1', kernel_quantizer=quantized_bits(6,0,alpha=1), bias_quantizer=quantized_bits(6,0,alpha=1),))
model.add(BatchNormalization())

# adding pruning 
pruning_params = {'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.50, final_sparsity=0.80, begin_step=200, end_step=1000)}
model = prune.prune_low_magnitude(model, **pruning_params)

print('=============================Model Summary=============================')
print(model.summary())
print('=======================================================================')
# Out:
# =============================Model Summary=============================
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  prune_low_magnitude_fc1 (Pr  (None, 2)                3204
#  uneLowMagnitude)
#
#  prune_low_magnitude_batch_n  (None, 2)                9
#  ormalization_1 (PruneLowMag
#  nitude)
#
# =================================================================
# Total params: 3,213
# Trainable params: 1,606
# Non-trainable params: 1,607
# _________________________________________________________________
# None
# =======================================================================

# %%
callbacks = [
        ModelCheckpoint(
        CHECKPOINT_FILENAME,
        monitor="val_loss",
        verbose=0,
        save_best_only=True,
        save_weights_only=False,
        save_freq="epoch",
    ),
    ReduceLROnPlateau(patience=PATIENCE, min_delta=1**-6),
    pruning_callbacks.UpdatePruningStep(),
]

# %% [markdown]
# ## Train the model

# %%
opt = Adam(learning_rate=INIT_LEARNING_RATE)
model.compile(
    optimizer=opt, 
    # loss=tf.keras.losses.BinaryCrossentropy(),
    loss=CategoricalCrossentropy(from_logits=True), 
    metrics=['accuracy']
)

history = model.fit(
    X_train_val, 
    y_train_val, 
    batch_size=BATCH_SIZE,
    epochs=EPOCHS, 
    validation_split=VALIDATION_SPLIT, 
    shuffle=True, 
    callbacks=callbacks
)
# Out:
# 2024-04-22 22:11:16.868639: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 24433916800 exceeds 10% of free system memory.
# Epoch 1/30
#   5/597 [..............................] - ETA: 35s - loss: 0.4504 - accuracy: 0.8076 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0202s vs `on_train_batch_end` time: 0.0219s). Check your callbacks.
# 595/597 [============================>.] - ETA: 0s - loss: 0.2217 - accuracy: 0.9394
# 2024-04-22 22:11:45.398246: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 10471683200 exceeds 10% of free system memory.
# 597/597 [==============================] - 29s 45ms/step - loss: 0.2216 - accuracy: 0.9394 - val_loss: 0.2175 - val_accuracy: 0.9393 - lr: 0.0100
# Epoch 2/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2257 - accuracy: 0.9343 - val_loss: 0.2282 - val_accuracy: 0.9323 - lr: 0.0100
# Epoch 3/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2277 - accuracy: 0.9331 - val_loss: 0.2279 - val_accuracy: 0.9325 - lr: 0.0100
# Epoch 4/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2276 - accuracy: 0.9332 - val_loss: 0.2278 - val_accuracy: 0.9326 - lr: 0.0100
# Epoch 5/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2276 - accuracy: 0.9332 - val_loss: 0.2276 - val_accuracy: 0.9330 - lr: 0.0100
# Epoch 6/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2276 - accuracy: 0.9332 - val_loss: 0.2276 - val_accuracy: 0.9329 - lr: 0.0100
# Epoch 7/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2276 - accuracy: 0.9332 - val_loss: 0.2276 - val_accuracy: 0.9328 - lr: 0.0100
# Epoch 8/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2275 - accuracy: 0.9332 - val_loss: 0.2276 - val_accuracy: 0.9329 - lr: 0.0100
# Epoch 9/30
# 597/597 [==============================] - 15s 24ms/step - loss: 0.2275 - accuracy: 0.9332 - val_loss: 0.2277 - val_accuracy: 0.9328 - lr: 0.0100
# Epoch 10/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2275 - accuracy: 0.9332 - val_loss: 0.2276 - val_accuracy: 0.9329 - lr: 0.0100
# Epoch 11/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2275 - accuracy: 0.9332 - val_loss: 0.2275 - val_accuracy: 0.9329 - lr: 0.0100
# Epoch 12/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2273 - accuracy: 0.9334 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-03
# Epoch 13/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2273 - accuracy: 0.9334 - val_loss: 0.2273 - val_accuracy: 0.9331 - lr: 1.0000e-03
# Epoch 14/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2273 - accuracy: 0.9334 - val_loss: 0.2273 - val_accuracy: 0.9331 - lr: 1.0000e-03
# Epoch 15/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2273 - accuracy: 0.9334 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-03
# Epoch 16/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2273 - accuracy: 0.9333 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-03
# Epoch 17/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2273 - accuracy: 0.9333 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-03
# Epoch 18/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2273 - accuracy: 0.9333 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-03
# Epoch 19/30
# 597/597 [==============================] - 15s 24ms/step - loss: 0.2273 - accuracy: 0.9334 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-03
# Epoch 20/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2273 - accuracy: 0.9334 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-03
# Epoch 21/30
# 597/597 [==============================] - 15s 24ms/step - loss: 0.2273 - accuracy: 0.9333 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-03
# Epoch 22/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2273 - accuracy: 0.9334 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-04
# Epoch 23/30
# 597/597 [==============================] - 14s 24ms/step - loss: 0.2273 - accuracy: 0.9334 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-04
# Epoch 24/30
# 597/597 [==============================] - 15s 24ms/step - loss: 0.2273 - accuracy: 0.9334 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-04
# Epoch 25/30
# 597/597 [==============================] - 15s 24ms/step - loss: 0.2273 - accuracy: 0.9334 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-04
# Epoch 26/30
# 597/597 [==============================] - 15s 24ms/step - loss: 0.2273 - accuracy: 0.9334 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-04
# Epoch 27/30
# 597/597 [==============================] - 15s 25ms/step - loss: 0.2273 - accuracy: 0.9334 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-04
# Epoch 28/30
# 597/597 [==============================] - 15s 24ms/step - loss: 0.2273 - accuracy: 0.9334 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-04
# Epoch 29/30
# 597/597 [==============================] - 14s 24ms/step - loss: 0.2273 - accuracy: 0.9334 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-04
# Epoch 30/30
# 597/597 [==============================] - 14s 24ms/step - loss: 0.2273 - accuracy: 0.9334 - val_loss: 0.2273 - val_accuracy: 0.9332 - lr: 1.0000e-04

# %% [markdown]
# Important: Pruning layers must be removed before saving to disk.

# %%
model = strip_pruning(model)
print(model.summary())
model.save(CHECKPOINT_FILENAME)

history_file = CHECKPOINT_FILENAME.replace(".h5", "-history.pkl")
with open(history_file, 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

print(f'Saving history to: {history_file}')
print(f'Saved checkpoint to: {CHECKPOINT_FILENAME}')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  fc1 (QDense)                (None, 2)                 1602
#
#  batch_normalization_1 (Batc  (None, 2)                8
#  hNormalization)
#
# =================================================================
# Total params: 1,610
# Trainable params: 1,606
# Non-trainable params: 4
# _________________________________________________________________
# None
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saving history to: models/model_150_550/bothshift_zeropadding_maxshift200_inc20_noisem4p4/qmodel_150_550-history.pkl
# Saved checkpoint to: models/model_150_550/bothshift_zeropadding_maxshift200_inc20_noisem4p4/qmodel_150_550.h5

# %% [markdown]
# ## Check performance

# %%
co = {}
_add_supported_quantized_objects(co)
model = load_model(CHECKPOINT_FILENAME, custom_objects=co, compile=False)
y_pred = model.predict(X_test)
print("Keras  Accuracy: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))))
# Out:
# 2024-04-22 22:19:11.627331: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 7756800000 exceeds 10% of free system memory.
# 75750/75750 [==============================] - 56s 707us/step
# Keras  Accuracy: 0.9329179042904291

# %%
X_test_unshifted = np.load(os.path.join(f'../data/qick_data/{START_WINDOW}_{END_WINDOW}', 'X_test.npy')).astype(np.float32)
y_test_unshifted = np.load(os.path.join(f'../data/qick_data/{START_WINDOW}_{END_WINDOW}', 'y_test.npy')).astype(np.float32)

y_pred_unshifted = model.predict(X_test_unshifted)
print("Keras  Accuracy on unshifted data: {}".format(accuracy_score(y_test_unshifted, np.argmax(y_pred_unshifted, axis=1))))
# Out:
# 3157/3157 [==============================] - 2s 678us/step
# Keras  Accuracy on unshifted data: 0.9357821782178218

# %% [markdown]
# ## TODO: add ROC curve
#
# To add an ROC curve, we need to normalize $y_\text{pred} \in [0,1]$. Right now it can take a range of values (I'm guessing because sigmoid is too expensive to run on hardware, whereas argmax can be implemented with basically just a switch).
#
# So then, what's an unbiased way to get back to $y_\text{pred} \in [0,1]$?
#
# ANSWER = Sigmoid, since that's what the model was trained with.

# %% [markdown]
# ## Check sparsity

# %%
num_layers = len(model.layers)
print(f'Number of layers: {num_layers}')

layer_names = ["fc1", "batch_normalization"]
for idx in range(num_layers):
    w = model.layers[idx].weights[0].numpy()
    h, b = np.histogram(w, bins=100)

    # plot weight distribution
    plt.figure(figsize=(7, 7))
    plt.bar(b[:-1], h, width=b[1] - b[0])
    plt.title(layer_names[idx])
    plt.semilogy()
    plt.savefig(f'model-dist-idx{idx}.png')

    print('% of zeros = {}'.format(np.sum(w == 0) / np.size(w)))
# Out:
# Number of layers: 2
# % of zeros = 0.8
# % of zeros = 0.0

# %% [markdown]
# ## Build the HLS model

# %%
sys.path.append("../utils")
from config import print_dict

from tensorflow.keras.models import load_model
from qkeras.utils import _add_supported_quantized_objects

# %%
# Load checkpoint 
co = {}
_add_supported_quantized_objects(co)
model = load_model(CHECKPOINT_FILENAME, custom_objects=co, compile=False)
y_pred = model.predict(X_test)

# Re-evalulate 
y_keras = model.predict(X_test)
print(f'Model acc: {accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_keras, axis=1))}')
print(model.summary())
# Out:
#     1/75750 [..............................] - ETA: 2:09:25
# 2024-04-22 18:53:03.548329: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 9696000000 exceeds 10% of free system memory.
# 25479/75750 [=========>....................] - ETA: 34s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 5
#       3 _add_supported_quantized_objects(co)
#       4 model = load_model(CHECKPOINT_FILENAME, custom_objects=co, compile=False)
# ----> 5 y_pred = model.predict(X_test)
#       7 # Re-evalulate
#       8 y_keras = model.predict(X_test)
#
# File /data/aelabd/miniforge3/envs/ml4qick-env/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /data/aelabd/miniforge3/envs/ml4qick-env/lib/python3.8/site-packages/keras/engine/training.py:2350, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2348 for step in data_handler.steps():
#    2349     callbacks.on_predict_batch_begin(step)
# -> 2350     tmp_batch_outputs = self.predict_function(iterator)
#    2351     if data_handler.should_sync:
#    2352         context.async_wait()
#
# File /data/aelabd/miniforge3/envs/ml4qick-env/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /data/aelabd/miniforge3/envs/ml4qick-env/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:880, in Function.__call__(self, *args, **kwds)
#     877 compiler = "xla" if self._jit_compile else "nonXla"
#     879 with OptionalXlaContext(self._jit_compile):
# --> 880   result = self._call(*args, **kwds)
#     882 new_tracing_count = self.experimental_get_tracing_count()
#     883 without_tracing = (tracing_count == new_tracing_count)
#
# File /data/aelabd/miniforge3/envs/ml4qick-env/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:919, in Function._call(self, *args, **kwds)
#     916 self._lock.release()
#     917 # In this case we have not created variables on the first call. So we can
#     918 # run the first trace but we should fail if variables are created.
# --> 919 results = self._variable_creation_fn(*args, **kwds)
#     920 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     921   raise ValueError("Creating variables on a non-first call to a function"
#     922                    " decorated with tf.function.")
#
# File /data/aelabd/miniforge3/envs/ml4qick-env/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:133, in TracingCompiler.__call__(self, *args, **kwargs)
#     130 """Calls a graph function specialized to the inputs."""
#     131 with self._lock:
#     132   (concrete_function,
# --> 133    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#     134 return concrete_function._call_flat(
#     135     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File /data/aelabd/miniforge3/envs/ml4qick-env/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:338, in TracingCompiler._maybe_define_function(self, args, kwargs)
#     333 # cache_key_deletion_observer is useless here. It's based on all captures.
#     334 # A new cache key will be built later when saving ConcreteFunction because
#     335 # only active captures should be saved.
#     336 lookup_func_key, _ = function_context.make_cache_key((args, kwargs),
#     337                                                      captures)
# --> 338 concrete_function = self._function_cache.lookup(lookup_func_key, True)
#     339 if concrete_function is not None:
#     340   return concrete_function, filtered_flat_args
#
# File /data/aelabd/miniforge3/envs/ml4qick-env/lib/python3.8/site-packages/tensorflow/core/function/polymorphism/function_cache.py:117, in FunctionCache.lookup(self, key, use_function_subtyping)
#     114 if not use_function_subtyping:
#     115   return self._primary.get(key, None)
# --> 117 dispatch_key = self._dispatch_table.dispatch(key)
#     118 if dispatch_key is not None:
#     119   return self._primary[dispatch_key]
#
# File /data/aelabd/miniforge3/envs/ml4qick-env/lib/python3.8/site-packages/tensorflow/core/function/polymorphism/type_dispatch.py:78, in TypeDispatchTable.dispatch(self, request)
#      76 """Returns the deepest subtype target if it exists in the table."""
#      77 # For known exact matches.
# ---> 78 if request in self._dispatch_table:
#      79   return request
#      81 # For known non-exact matches.
#      82 # (self._dispatch cache does not contain exact matches)
#
# File /data/aelabd/miniforge3/envs/ml4qick-env/lib/python3.8/site-packages/tensorflow/core/function/polymorphism/function_cache.py:87, in FunctionCacheKey.__eq__(self, other)
#      83 if not isinstance(other, FunctionCacheKey):
#      84   return False
#      86 return (self.call_context == other.call_context and
# ---> 87         self.function_type == other.function_type)
#
# File /data/aelabd/miniforge3/envs/ml4qick-env/lib/python3.8/site-packages/tensorflow/core/function/polymorphism/function_type.py:242, in FunctionType.__eq__(self, other)
#     239 if not isinstance(other, FunctionType):
#     240   return NotImplemented
# --> 242 return (self.parameters, self.captures) == (other.parameters,
#     243                                             other.captures)
#
# File /data/aelabd/miniforge3/envs/ml4qick-env/lib/python3.8/site-packages/tensorflow/core/function/polymorphism/function_type.py:97, in Parameter.__eq__(self, other)
#      94   else:
#      95     return None
# ---> 97 def __eq__(self, other: Any) -> bool:
#      98   if not isinstance(other, Parameter):
#      99     return NotImplemented
#
# KeyboardInterrupt:

# %%
# Create HLS configuration 

# Model params: Default precision, reuse factor
HLSConfig = {}
HLSConfig['Model'] = {}
HLSConfig['Model']['Precision'] = 'ap_fixed<16,6>'  # Default precision. Recall syntax: ap_fixed<total_bits, integer_bits>
HLSConfig['Model']['ReuseFactor'] = 1

HLSConfig['LayerName'] = {}
for layer in ['fc1_input', 'fc1', 'fc1_linear', 'batch_normalization']:
    # Layer params: Precision, whether or not to trace
    HLSConfig['LayerName'][layer] = {}
    HLSConfig['LayerName'][layer]['Precision'] = {}
    HLSConfig['LayerName'][layer]['Trace'] = True

# Input - ZCU216 uses 14-bit ADCS  
# Question: 1sn't 16,6 a lot? I remember getting down to like 7 bits total for the GNN tracking project, recreated like 94% accuracy. How accurate do we need to be?
HLSConfig['LayerName']['fc1_input']['Precision'] = 'ap_fixed<14,14>'  # So no fractional bits, prob result of quantization
# Fc
HLSConfig['LayerName']['fc1']['Precision']['result'] = 'ap_fixed<18,18>' 
HLSConfig['LayerName']['fc1']['accum_t'] = 'ap_fixed<18,18>'
# Fc Linear
HLSConfig['LayerName']['fc1_linear']['Precision']['result'] = 'ap_fixed<18,18>'
# Batchnormalization
HLSConfig['LayerName']['batch_normalization']['Precision']['scale'] = 'ap_fixed<20,3>'
HLSConfig['LayerName']['batch_normalization']['Precision']['bias'] = 'ap_fixed<20,3>'
HLSConfig['LayerName']['batch_normalization']['Precision']['result'] = 'ap_fixed<16,6>'

print_dict(HLSConfig)
# Out:
# Model
#   Precision:         ap_fixed<16,6>
#   ReuseFactor:       1
# LayerName
#   fc1_input
#     Precision:       ap_fixed<14,14>
#     Trace:           True
#   fc1
#     Precision
#       result:        ap_fixed<18,18>
#     Trace:           True
#     accum_t:         ap_fixed<18,18>
#   fc1_linear
#     Precision
#       result:        ap_fixed<18,18>
#     Trace:           True
#   batch_normalization
#     Precision
#       scale:         ap_fixed<20,3>
#       bias:          ap_fixed<20,3>
#       result:        ap_fixed<16,6>
#     Trace:           True

# %%
OutputDir =  os.path.join(MODEL_DIR, 'hls4ml_prj')
XilinxPart = 'xczu49dr-ffvf1760-2-e' # <-- CHANGE PART HERE
IOType = 'io_parallel' # 'io_stream'
ClockPeriod = 3.225  # 3.225ns (307.2 MHz) # <-- How does this relate to the frequency of the IQ timeseries data? Serialization must be bufferized by WINDOW_SIZE, at least.
            # Is the clock frequency exactly equal to the timeseries frequency? I.e. we sample once per clock cycle until we've bufferized a dataset of size WINDOW_SIZE, and then pass to the NN for inference?
HLSFig = OutputDir+'model.png'

hls_model = hls4ml.converters.convert_from_keras_model(
    model=model,
    hls_config=HLSConfig,
    output_dir=OutputDir,
    part=XilinxPart,
    io_type=IOType,
    clock_period=ClockPeriod,
)

print(f"Creating hls4ml project directory {OutputDir}")
hls_model.compile()  # Must compile for C Sim. 

# Visualize model
hls4ml.utils.plot_model(
    hls_model, show_shapes=True, show_precision=True, to_file=HLSFig
)
# Out:
# Interpreting Sequential
# Topology:
# Layer name: fc1_input, layer type: InputLayer, input shapes: [[None, 1540]], output shape: [None, 1540]
# Layer name: fc1, layer type: QDense, input shapes: [[None, 1540]], output shape: [None, 2]
# Layer name: batch_normalization, layer type: BatchNormalization, input shapes: [[None, 2]], output shape: [None, 2]
# Creating HLS model
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "fc1" (Dense)
# Creating hls4ml project directory hls4ml_prj/
# Writing HLS project
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done

# %% [markdown]
# ## Check performance

# %%
# Trace output 
#y_hls = hls_model.predict(np.ascontiguousarray(X_test.astype(np.float32))) 
y_hls, hls_trace = hls_model.trace(np.ascontiguousarray(X_test.astype(np.float32))) 
y_hls = np.argmax(y_hls, axis=1)

print(f'Keras Acc: {accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_keras, axis=1))*100:.5}%')
print(f'HLS Acc: {accuracy_score(np.argmax(y_test, axis=1), y_hls)*100:.5}:%')
print(f'CKA: {accuracy_score(np.argmax(y_keras, axis=1), y_hls)*100:.5}%')
# Out:
# Recompiling myproject with tracing
# Writing HLS project
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done
# Keras Acc: 96.128%
# HLS Acc: 96.148:%
# CKA: 99.929%

# %% [markdown]
# ## Correlation plots (Keras vs HLS)
# Let's compare the output of the Qkeras and HLS model. If properly configured, the HLS activations will be aligned with the Qkeras model.

# %%
# y_hls, hls_trace = hls_model.trace(np.ascontiguousarray(X_test.astype(np.float32))) 
keras_trace = hls4ml.model.profiling.get_ymodel_keras(model, X_test.astype(np.float32)) 

print(f'HLS Keys: {hls_trace.keys()}')
print(f'Keras Keys: {keras_trace.keys()}')
# Out:
# 3157/3157 [==============================] - 3s 824us/step
# Done taking outputs for Keras model.
# HLS Keys: dict_keys(['fc1', 'batch_normalization'])
# Keras Keys: dict_keys(['fc1', 'batch_normalization'])

# %%
layers = ['fc1', 'batch_normalization']

for idx, layer in enumerate(layers):
    keras_layer, hls_layer = keras_trace[layer], hls_trace[layer]
    try:
        diff = np.average(np.abs(keras_layer - hls_layer ))
        print(f'{layer}', '\t\t', diff)
        
        plt.figure(figsize=(7, 5))

        plt.scatter(hls_layer.flatten(), keras_layer.flatten())
        min_x = min(keras_layer.min(), hls_layer.min())
        max_x = min(keras_layer.max(), hls_layer.max())

        onnx_min, onnx_max = keras_layer.flatten().min(), keras_layer.flatten().max()
        hls_min, hls_max = hls_layer.flatten().min(), hls_layer.flatten().max()
        
        print(f'hls/keras min: {hls_min}/{onnx_min}')
        print(f'hls/keras max: {hls_max}/{onnx_max}')
        
        plt.plot([min_x, max_x], [min_x, max_x], c='red')
        plt.axhline(min_x, c='red')
        plt.axhline(max_x, c='red')

        plt.title(f'(hls) {layer} -- (keras) {layer}')
        plt.xlabel(f'hls4ml - [{hls_min:.3f},  {hls_max:.3f}]')
        plt.ylabel(f'keras - [{onnx_min:.3f},  {onnx_max:.3f}]')
        plt.yscale('linear')
    except Exception as e:
        print(e)
# Out:
# fc1 		 140.00832
# hls/keras min: -67506.0/-67367.71875
# hls/keras max: 68253.0/68396.0
# batch_normalization 		 0.04689832
# hls/keras min: -5.984375/-6.145636558532715
# hls/keras max: 6.048828125/6.1646833419799805

# %% [markdown]
# ## Synthesize

# %%
tic = time.time()
hls_model.build(
    csim=False,
    synth=True,
    cosim=False,
    export=False,
    vsynth=True,
)
toc = time.time()
dur = toc - tic
print(f"Duration: {dur//60} minutes, {dur%60} seconds\n")
# Out:
# ****** Vivado(TM) HLS - High-Level Synthesis from C, C++ and SystemC v2020.1.1 (64-bit)
#   **** SW Build 2960000 on Wed Aug  5 22:57:21 MDT 2020
#   **** IP Build 2956692 on Thu Aug  6 01:41:30 MDT 2020
#     ** Copyright 1986-2020 Xilinx, Inc. All Rights Reserved.
#
# source /opt/local/Xilinx/Vivado/2020.1/scripts/vivado_hls/hls.tcl -notrace
# INFO: Applying HLS Y2K22 patch v1.2 for IP revision
# INFO: [HLS 200-10] Running '/opt/local/Xilinx/Vivado/2020.1/bin/unwrapped/lnx64.o/vivado_hls'
# INFO: [HLS 200-10] For user 'aelabd' on host 'correlator3.fnal.gov' (Linux_x86_64 version 3.10.0-1160.99.1.el7.x86_64) on Sun Apr 21 16:48:45 CDT 2024
# INFO: [HLS 200-10] On os "Scientific Linux release 7.9 (Nitrogen)"
# INFO: [HLS 200-10] In directory '/data/aelabd/ml-quantum-readout/notebooks/hls4ml_prj'
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-10] Opening project '/data/aelabd/ml-quantum-readout/notebooks/hls4ml_prj/myproject_prj'.
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-10] Opening solution '/data/aelabd/ml-quantum-readout/notebooks/hls4ml_prj/myproject_prj/solution1'.
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 3.225ns.
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 0.403ns.
# INFO: [HLS 200-10] Setting target device to 'xczu49dr-ffvf1760-2-e'
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# INFO: [XFORM 203-1161] The maximum of name length is set into 80.
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# INFO: [XFORM 203-1161] The maximum of name length is set into 80.
# ***** C/RTL SYNTHESIS *****
# INFO: [SCHED 204-61] Option 'relax_ii_for_timing' is enabled, will increase II to preserve clock frequency constraints.
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# INFO: [HLS 200-111] Finished Linking Time (s): cpu = 00:00:17 ; elapsed = 00:00:18 . Memory (MB): peak = 1758.262 ; gain = 1231.906 ; free physical = 8555 ; free virtual = 177103
# INFO: [HLS 200-111] Finished Checking Pragmas Time (s): cpu = 00:00:17 ; elapsed = 00:00:18 . Memory (MB): peak = 1758.262 ; gain = 1231.906 ; free physical = 8555 ; free virtual = 177103
# INFO: [HLS 200-10] Starting code transformations ...
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<6, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_latency.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' into 'myproject' (firmware/myproject.cpp:37).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 3, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::normalize<ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_batchnorm.h:54).
# INFO: [HLS 200-111] Finished Standard Transforms Time (s): cpu = 00:00:18 ; elapsed = 00:00:19 . Memory (MB): peak = 1758.262 ; gain = 1231.906 ; free physical = 8533 ; free virtual = 177087
# INFO: [HLS 200-10] Checking synthesizability ...
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' into 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_latency.h:66) automatically.
# INFO: [HLS 200-111] Finished Checking Synthesizability Time (s): cpu = 00:00:18 ; elapsed = 00:00:19 . Memory (MB): peak = 1758.262 ; gain = 1231.906 ; free physical = 8532 ; free virtual = 177086
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::normalize<ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_batchnorm.h:37:47).
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_latency.h:17:48).
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_batchnorm.h:52) in function 'nnet::normalize<ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:37) in function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 1540.
# INFO: [HLS 200-489] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:40) in function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:48) in function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:54) in function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 1540.
# INFO: [HLS 200-489] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:56) in function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:64) in function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 2.
# INFO: [XFORM 203-131] Reshaping array 'fc1_input.V' (firmware/myproject.cpp:7) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'layer4_out.V' (firmware/myproject.cpp:8) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'layer2_out.V' (firmware/myproject.cpp:35) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'b2.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'mult.V' (firmware/nnet_utils/nnet_dense_latency.h:17) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'acc.V' (firmware/nnet_utils/nnet_dense_latency.h:18) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 's4.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'b4.V'  in dimension 1 completely.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' into 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_latency.h:66) automatically.
# INFO: [XFORM 203-622] Instantiating function 'nnet::normalize<ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>'(firmware/nnet_utils/nnet_batchnorm.h:42:1) to 'nnet::normalize<ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>.0' at call site (firmware/myproject.cpp:42) by setting 'scale[0].V' to 's4.V.0'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::normalize<ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>.0'(firmware/nnet_utils/nnet_batchnorm.h:42:1) to 'nnet::normalize<ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>.0.0' at call site (firmware/myproject.cpp:42) by setting 'scale[1].V' to 's4.V.1'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::normalize<ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>.0.0'(firmware/nnet_utils/nnet_batchnorm.h:42:1) to 'nnet::normalize<ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>.0.0.0' at call site (firmware/myproject.cpp:42) by setting 'bias[0].V' to 'b4.V.0'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::normalize<ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>.0.0.0'(firmware/nnet_utils/nnet_batchnorm.h:42:1) to 'nnet::normalize<ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>.0.0.0.0' at call site (firmware/myproject.cpp:42) by setting 'bias[1].V' to 'b4.V.1'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>'(firmware/nnet_utils/nnet_dense_latency.h:26:27) to 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>.0' by setting 'weights.V' to 'w2.V'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>.0'(firmware/nnet_utils/nnet_dense_latency.h:26:27) to 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>.0.0' by setting 'biases[0].V' to 'b2.V.0'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>.0.0'(firmware/nnet_utils/nnet_dense_latency.h:26:27) to 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>.0.0.0' by setting 'biases[1].V' to 'b2.V.1'.
# INFO: [XFORM 203-11] Balancing expressions in function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>.0.0.0' (firmware/nnet_utils/nnet_mult.h:26:9)...613 expression(s) balanced.
# INFO: [HLS 200-111] Finished Pre-synthesis Time (s): cpu = 00:03:11 ; elapsed = 00:03:14 . Memory (MB): peak = 8987.105 ; gain = 8460.750 ; free physical = 4461 ; free virtual = 173014
# WARNING: [XFORM 203-631] Renaming function 'nnet::normalize<ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>.0.0.0.0' to 'normalize<ap_fixed<18, 18, 5, 3, 0>, ap_fixed<16, 6, 5, 3, 0>, config4>.0.0.0.0' (firmware/nnet_utils/nnet_batchnorm.h:42:1)
# WARNING: [XFORM 203-631] Renaming function 'nnet::dense_latency<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 18, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>.0.0.0' to 'dense_latency<ap_fixed,ap_fixed<18,18,5,3,0>,config2>.0.0.0' (firmware/nnet_utils/nnet_dense_latency.h:26:9)
# INFO: [HLS 200-111] Finished Architecture Synthesis Time (s): cpu = 00:03:20 ; elapsed = 00:03:23 . Memory (MB): peak = 8987.105 ; gain = 8460.750 ; free physical = 4463 ; free virtual = 173016
# INFO: [HLS 200-10] Starting hardware synthesis ...
# INFO: [HLS 200-10] Synthesizing 'myproject' ...
# WARNING: [SYN 201-103] Legalizing function name 'dense_latency<ap_fixed,ap_fixed<18,18,5,3,0>,config2>.0.0.0' to 'dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0'.
# WARNING: [SYN 201-103] Legalizing function name 'normalize<ap_fixed<18, 18, 5, 3, 0>, ap_fixed<16, 6, 5, 3, 0>, config4>.0.0.0.0' to 'normalize_ap_fixed_18_18_5_3_0_ap_fixed_16_6_5_3_0_config4_0_0_0_0'.
# WARNING: [SYN 201-223] Checking resource limit in 'normalize<ap_fixed<18, 18, 5, 3, 0>, ap_fixed<16, 6, 5, 3, 0>, config4>.0.0.0.0': cannot find any operation of 'mul'.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining function 'dense_latency<ap_fixed,ap_fixed<18,18,5,3,0>,config2>.0.0.0'.
# INFO: [SCHED 204-61] Pipelining result : Target II = 1, Final II = 1, Depth = 4.
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 205.11 seconds; current allocated memory: 251.810 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Starting global binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 12.67 seconds; current allocated memory: 271.126 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'normalize_ap_fixed_18_18_5_3_0_ap_fixed_16_6_5_3_0_config4_0_0_0_0'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining function 'normalize<ap_fixed<18, 18, 5, 3, 0>, ap_fixed<16, 6, 5, 3, 0>, config4>.0.0.0.0'.
# INFO: [SCHED 204-61] Pipelining result : Target II = 1, Final II = 1, Depth = 1.
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 11.29 seconds; current allocated memory: 272.254 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 0.05 seconds; current allocated memory: 272.352 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'myproject'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining function 'myproject'.
# INFO: [SCHED 204-61] Pipelining result : Target II = 1, Final II = 1, Depth = 5.
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 0.06 seconds; current allocated memory: 272.417 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 0.98 seconds; current allocated memory: 273.098 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-104] Estimated max fanout for 'dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0' is 21560 from HDL expression: (1'b1 == ap_ce)
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0'.
# INFO: [HLS 200-111]  Elapsed time: 5.73 seconds; current allocated memory: 308.095 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'normalize_ap_fixed_18_18_5_3_0_ap_fixed_16_6_5_3_0_config4_0_0_0_0'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'normalize_ap_fixed_18_18_5_3_0_ap_fixed_16_6_5_3_0_config4_0_0_0_0'.
# INFO: [HLS 200-111]  Elapsed time: 16.39 seconds; current allocated memory: 379.058 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'myproject'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/fc1_input_V' to 'ap_vld'.
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer4_out_0_V' to 'ap_vld'.
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer4_out_1_V' to 'ap_vld'.
# INFO: [RTGEN 206-500] Setting interface mode on function 'myproject' to 'ap_ctrl_hs'.
# INFO: [RTGEN 206-104] Estimated max fanout for 'myproject' is 21566 from HDL expression: ap_rst
# INFO: [RTGEN 206-100] Finished creating RTL model for 'myproject'.
# INFO: [HLS 200-111]  Elapsed time: 0.91 seconds; current allocated memory: 379.689 MB.
# INFO: [HLS 200-789] **** Estimated Fmax: 390.90 MHz
# INFO: [HLS 200-111] Finished generating all RTL models Time (s): cpu = 00:04:16 ; elapsed = 00:04:25 . Memory (MB): peak = 8987.105 ; gain = 8460.750 ; free physical = 4500 ; free virtual = 173014
# INFO: [VHDL 208-304] Generating VHDL RTL for myproject.
# INFO: [VLOG 209-307] Generating Verilog RTL for myproject.
# ***** C/RTL SYNTHESIS COMPLETED IN 0h4m21s *****
# ***** VIVADO SYNTHESIS *****
#
# ****** Vivado v2020.1.1 (64-bit)
#   **** SW Build 2960000 on Wed Aug  5 22:57:21 MDT 2020
#   **** IP Build 2956692 on Thu Aug  6 01:41:30 MDT 2020
#     ** Copyright 1986-2020 Xilinx, Inc. All Rights Reserved.
#
# source vivado_synth.tcl
# # set tcldir [file dirname [info script]]
# # source [file join $tcldir project.tcl]
# ## variable project_name
# ## set project_name "myproject"
# ## variable backend
# ## set backend "vivado"
# ## variable part
# ## set part "xczu49dr-ffvf1760-2-e"
# ## variable clock_period
# ## set clock_period 3.225
# ## variable clock_uncertainty
# ## set clock_uncertainty 12.5%
# ## variable version
# ## set version "1.0.0"
# # add_files ${project_name}_prj/solution1/syn/vhdl
# # synth_design -top ${project_name} -part $part
# Command: synth_design -top myproject -part xczu49dr-ffvf1760-2-e
# Starting synth_design
# Attempting to get a license for feature 'Synthesis' and/or device 'xczu49dr'
# INFO: [Common 17-349] Got license for feature 'Synthesis' and/or device 'xczu49dr'
# INFO: [Synth 8-7079] Multithreading enabled for synth_design using a maximum of 4 processes.
# INFO: [Synth 8-7078] Launching helper process for spawning children vivado processes
# INFO: [Synth 8-7075] Helper process launched with PID 35442
# load diablo GTM unisim library
# ---------------------------------------------------------------------------------
# Starting Synthesize : Time (s): cpu = 00:00:02 ; elapsed = 00:00:04 . Memory (MB): peak = 2231.344 ; gain = 0.000 ; free physical = 3453 ; free virtual = 172395
# ---------------------------------------------------------------------------------
# INFO: [Synth 8-638] synthesizing module 'myproject' [/data/aelabd/ml-quantum-readout/notebooks/hls4ml_prj/myproject_prj/solution1/syn/vhdl/myproject.vhd:29]
# INFO: [Synth 8-3491] module 'dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0' declared at '/data/aelabd/ml-quantum-readout/notebooks/hls4ml_prj/myproject_prj/solution1/syn/vhdl/dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0.vhd:12' bound to instance 'grp_dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0_fu_54' of component 'dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0' [/data/aelabd/ml-quantum-readout/notebooks/hls4ml_prj/myproject_prj/solution1/syn/vhdl/myproject.vhd:106]
# INFO: [Synth 8-638] synthesizing module 'dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0' [/data/aelabd/ml-quantum-readout/notebooks/hls4ml_prj/myproject_prj/solution1/syn/vhdl/dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0.vhd:23]
# INFO: [Synth 8-256] done synthesizing module 'dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0' (1#1) [/data/aelabd/ml-quantum-readout/notebooks/hls4ml_prj/myproject_prj/solution1/syn/vhdl/dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0.vhd:23]
# INFO: [Synth 8-3491] module 'normalize_ap_fixed_18_18_5_3_0_ap_fixed_16_6_5_3_0_config4_0_0_0_0' declared at '/data/aelabd/ml-quantum-readout/notebooks/hls4ml_prj/myproject_prj/solution1/syn/vhdl/normalize_ap_fixed_18_18_5_3_0_ap_fixed_16_6_5_3_0_config4_0_0_0_0.vhd:12' bound to instance 'call_ret1_normalize_ap_fixed_18_18_5_3_0_ap_fixed_16_6_5_3_0_config4_0_0_0_0_fu_60' of component 'normalize_ap_fixed_18_18_5_3_0_ap_fixed_16_6_5_3_0_config4_0_0_0_0' [/data/aelabd/ml-quantum-readout/notebooks/hls4ml_prj/myproject_prj/solution1/syn/vhdl/myproject.vhd:115]
# INFO: [Synth 8-638] synthesizing module 'normalize_ap_fixed_18_18_5_3_0_ap_fixed_16_6_5_3_0_config4_0_0_0_0' [/data/aelabd/ml-quantum-readout/notebooks/hls4ml_prj/myproject_prj/solution1/syn/vhdl/normalize_ap_fixed_18_18_5_3_0_ap_fixed_16_6_5_3_0_config4_0_0_0_0.vhd:22]
# INFO: [Synth 8-256] done synthesizing module 'normalize_ap_fixed_18_18_5_3_0_ap_fixed_16_6_5_3_0_config4_0_0_0_0' (2#1) [/data/aelabd/ml-quantum-readout/notebooks/hls4ml_prj/myproject_prj/solution1/syn/vhdl/normalize_ap_fixed_18_18_5_3_0_ap_fixed_16_6_5_3_0_config4_0_0_0_0.vhd:22]
# INFO: [Synth 8-256] done synthesizing module 'myproject' (3#1) [/data/aelabd/ml-quantum-readout/notebooks/hls4ml_prj/myproject_prj/solution1/syn/vhdl/myproject.vhd:29]
# ---------------------------------------------------------------------------------
# Finished Synthesize : Time (s): cpu = 00:00:06 ; elapsed = 00:00:08 . Memory (MB): peak = 2231.344 ; gain = 0.000 ; free physical = 3396 ; free virtual = 172342
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Finished Constraint Validation : Time (s): cpu = 00:00:07 ; elapsed = 00:00:09 . Memory (MB): peak = 2231.344 ; gain = 0.000 ; free physical = 3406 ; free virtual = 172351
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Start Loading Part and Timing Information
# ---------------------------------------------------------------------------------
# Loading part: xczu49dr-ffvf1760-2-e
# INFO: [Synth 8-6742] Reading net delay rules and data
# ---------------------------------------------------------------------------------
# Finished Loading Part and Timing Information : Time (s): cpu = 00:00:07 ; elapsed = 00:00:10 . Memory (MB): peak = 2239.348 ; gain = 8.004 ; free physical = 3406 ; free virtual = 172351
# ---------------------------------------------------------------------------------
# INFO: [Device 21-403] Loading part xczu49dr-ffvf1760-2-e
# ---------------------------------------------------------------------------------
# Finished RTL Optimization Phase 2 : Time (s): cpu = 00:00:16 ; elapsed = 00:00:17 . Memory (MB): peak = 2239.352 ; gain = 8.008 ; free physical = 3201 ; free virtual = 172159
# ---------------------------------------------------------------------------------
# No constraint files found.
# ---------------------------------------------------------------------------------
# Start RTL Component Statistics
# ---------------------------------------------------------------------------------
# Detailed RTL Component Info :
# +---Adders :
# 	   3 Input   23 Bit       Adders := 2
# 	   3 Input   19 Bit       Adders := 41
# 	   2 Input   19 Bit       Adders := 1
# 	   3 Input   18 Bit       Adders := 298
# 	   2 Input   18 Bit       Adders := 85
# 	   8 Input   18 Bit       Adders := 2
# 	  10 Input   18 Bit       Adders := 2
# 	   9 Input   18 Bit       Adders := 1
# 	   6 Input   18 Bit       Adders := 1
# 	   3 Input   17 Bit       Adders := 15
# 	   2 Input   17 Bit       Adders := 69
# 	   2 Input   16 Bit       Adders := 96
# 	   3 Input   16 Bit       Adders := 10
# 	   2 Input   15 Bit       Adders := 144
# 	   3 Input   15 Bit       Adders := 13
# 	   2 Input   14 Bit       Adders := 176
# 	   2 Input   13 Bit       Adders := 28
# 	   2 Input   12 Bit       Adders := 1
# +---Registers :
# 	            21560 Bit    Registers := 1
# 	               18 Bit    Registers := 18
# 	               17 Bit    Registers := 40
# 	               16 Bit    Registers := 9
# 	               15 Bit    Registers := 105
# 	               14 Bit    Registers := 131
# 	               13 Bit    Registers := 35
# 	               12 Bit    Registers := 3
# 	               10 Bit    Registers := 1
# 	                1 Bit    Registers := 6
# +---Muxes :
# 	   2 Input 21560 Bit        Muxes := 1
# 	   2 Input   18 Bit        Muxes := 2
# 	   2 Input    1 Bit        Muxes := 2
# ---------------------------------------------------------------------------------
# Finished RTL Component Statistics
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Start Part Resource Summary
# ---------------------------------------------------------------------------------
# Part Resources:
# DSPs: 4272 (col length:192)
# BRAMs: 2160 (col length: RAMB18 192 RAMB36 96)
# ---------------------------------------------------------------------------------
# Finished Part Resource Summary
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Start Cross Boundary and Area Optimization
# ---------------------------------------------------------------------------------
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6636]' (FDE) to 'tmp_561_reg_162860_reg__31'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6637]' (FDE) to 'tmp_561_reg_162860_reg__11'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6638]' (FDE) to 'tmp_561_reg_162860_reg__10'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6639]' (FDE) to 'tmp_561_reg_162860_reg__9'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6640]' (FDE) to 'tmp_561_reg_162860_reg__8'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6641]' (FDE) to 'tmp_561_reg_162860_reg__7'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6642]' (FDE) to 'tmp_561_reg_162860_reg__6'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6643]' (FDE) to 'tmp_561_reg_162860_reg__5'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6644]' (FDE) to 'tmp_561_reg_162860_reg__4'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6645]' (FDE) to 'tmp_561_reg_162860_reg__3'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6646]' (FDE) to 'tmp_561_reg_162860_reg__2'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6647]' (FDE) to 'tmp_561_reg_162860_reg__1'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6648]' (FDE) to 'tmp_561_reg_162860_reg__0'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6649]' (FDE) to 'tmp_561_reg_162860_reg'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6594]' (FDE) to 'tmp_560_reg_162855_reg__12'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6595]' (FDE) to 'tmp_560_reg_162855_reg__11'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6596]' (FDE) to 'tmp_560_reg_162855_reg__10'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6597]' (FDE) to 'tmp_560_reg_162855_reg__9'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6598]' (FDE) to 'tmp_560_reg_162855_reg__8'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6599]' (FDE) to 'tmp_560_reg_162855_reg__7'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6600]' (FDE) to 'tmp_560_reg_162855_reg__6'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6601]' (FDE) to 'tmp_560_reg_162855_reg__5'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6602]' (FDE) to 'tmp_560_reg_162855_reg__4'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6603]' (FDE) to 'tmp_560_reg_162855_reg__3'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6604]' (FDE) to 'tmp_560_reg_162855_reg__2'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6605]' (FDE) to 'tmp_560_reg_162855_reg__1'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6606]' (FDE) to 'tmp_560_reg_162855_reg__0'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6607]' (FDE) to 'tmp_560_reg_162855_reg'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7154]' (FDE) to 'tmp_599_reg_162911_reg__12'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7155]' (FDE) to 'tmp_599_reg_162911_reg__11'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7156]' (FDE) to 'tmp_599_reg_162911_reg__10'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7157]' (FDE) to 'tmp_599_reg_162911_reg__9'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7158]' (FDE) to 'tmp_599_reg_162911_reg__8'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7159]' (FDE) to 'tmp_599_reg_162911_reg__7'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7160]' (FDE) to 'tmp_599_reg_162911_reg__6'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7161]' (FDE) to 'tmp_599_reg_162911_reg__5'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7162]' (FDE) to 'tmp_599_reg_162911_reg__4'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7163]' (FDE) to 'tmp_599_reg_162911_reg__3'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7164]' (FDE) to 'tmp_599_reg_162911_reg__2'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7165]' (FDE) to 'tmp_599_reg_162911_reg__1'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7166]' (FDE) to 'tmp_599_reg_162911_reg__0'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7167]' (FDE) to 'tmp_599_reg_162911_reg'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7210]' (FDE) to 'tmp_602_reg_162916_reg__12'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7211]' (FDE) to 'tmp_602_reg_162916_reg__11'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7212]' (FDE) to 'tmp_602_reg_162916_reg__10'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7213]' (FDE) to 'tmp_602_reg_162916_reg__9'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7214]' (FDE) to 'tmp_602_reg_162916_reg__8'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7215]' (FDE) to 'tmp_602_reg_162916_reg__7'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7216]' (FDE) to 'tmp_602_reg_162916_reg__6'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7217]' (FDE) to 'tmp_602_reg_162916_reg__5'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7218]' (FDE) to 'tmp_602_reg_162916_reg__4'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7219]' (FDE) to 'tmp_602_reg_162916_reg__3'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7220]' (FDE) to 'tmp_602_reg_162916_reg__2'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7221]' (FDE) to 'tmp_602_reg_162916_reg__1'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7222]' (FDE) to 'tmp_602_reg_162916_reg__0'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[7223]' (FDE) to 'tmp_602_reg_162916_reg'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5474]' (FDE) to 'tmp_408_reg_162774_reg__12'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5475]' (FDE) to 'tmp_408_reg_162774_reg__11'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5476]' (FDE) to 'tmp_408_reg_162774_reg__10'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5477]' (FDE) to 'tmp_408_reg_162774_reg__9'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5478]' (FDE) to 'tmp_408_reg_162774_reg__8'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5479]' (FDE) to 'tmp_408_reg_162774_reg__7'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5480]' (FDE) to 'tmp_408_reg_162774_reg__6'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5481]' (FDE) to 'tmp_408_reg_162774_reg__5'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5482]' (FDE) to 'tmp_408_reg_162774_reg__4'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5483]' (FDE) to 'tmp_408_reg_162774_reg__3'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5484]' (FDE) to 'tmp_408_reg_162774_reg__2'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5485]' (FDE) to 'tmp_408_reg_162774_reg__1'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5486]' (FDE) to 'tmp_408_reg_162774_reg__0'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5487]' (FDE) to 'tmp_408_reg_162774_reg'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5642]' (FDE) to 'tmp_429_reg_162800_reg__12'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5643]' (FDE) to 'tmp_429_reg_162800_reg__11'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5644]' (FDE) to 'tmp_429_reg_162800_reg__10'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5645]' (FDE) to 'tmp_429_reg_162800_reg__9'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5646]' (FDE) to 'tmp_429_reg_162800_reg__8'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5647]' (FDE) to 'tmp_429_reg_162800_reg__7'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5648]' (FDE) to 'tmp_429_reg_162800_reg__6'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5649]' (FDE) to 'tmp_429_reg_162800_reg__5'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5650]' (FDE) to 'tmp_429_reg_162800_reg__4'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5651]' (FDE) to 'tmp_429_reg_162800_reg__3'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5652]' (FDE) to 'tmp_429_reg_162800_reg__2'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5653]' (FDE) to 'tmp_429_reg_162800_reg__1'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5654]' (FDE) to 'tmp_429_reg_162800_reg__0'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5655]' (FDE) to 'tmp_429_reg_162800_reg'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5082]' (FDE) to 'tmp_367_reg_162744_reg__12'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5083]' (FDE) to 'tmp_367_reg_162744_reg__11'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5084]' (FDE) to 'tmp_367_reg_162744_reg__10'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5085]' (FDE) to 'tmp_367_reg_162744_reg__9'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5086]' (FDE) to 'tmp_367_reg_162744_reg__8'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5087]' (FDE) to 'tmp_367_reg_162744_reg__7'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5088]' (FDE) to 'tmp_367_reg_162744_reg__6'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5089]' (FDE) to 'tmp_367_reg_162744_reg__5'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5090]' (FDE) to 'tmp_367_reg_162744_reg__4'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5091]' (FDE) to 'tmp_367_reg_162744_reg__3'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5092]' (FDE) to 'tmp_367_reg_162744_reg__2'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5093]' (FDE) to 'tmp_367_reg_162744_reg__1'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5094]' (FDE) to 'tmp_367_reg_162744_reg__0'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[5095]' (FDE) to 'tmp_367_reg_162744_reg'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6776]' (FDE) to 'tmp_570_reg_162880_reg__12'
# INFO: [Synth 8-3886] merging instance 'data_V_read_int_reg_reg[6777]' (FDE) to 'tmp_570_reg_162880_reg__11'
# INFO: [Common 17-14] Message 'Synth 8-3886' appears 100 times and further instances of the messages will be disabled. Use the Tcl command set_msg_config to change the current settings.
# INFO: [Common 17-14] Message 'Synth 8-3886' appears 100 times and further instances of the messages will be disabled. Use the Tcl command set_msg_config to change the current settings.
# INFO: [Synth 8-3333] propagating constant 1 across sequential element (\ap_CS_fsm_reg[0] )
# ---------------------------------------------------------------------------------
# Finished Cross Boundary and Area Optimization : Time (s): cpu = 00:00:33 ; elapsed = 00:01:37 . Memory (MB): peak = 2947.844 ; gain = 716.500 ; free physical = 828 ; free virtual = 165956
# ---------------------------------------------------------------------------------
# No constraint files found.
# ---------------------------------------------------------------------------------
# Start Timing Optimization
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Finished Timing Optimization : Time (s): cpu = 00:00:36 ; elapsed = 00:01:40 . Memory (MB): peak = 2949.914 ; gain = 718.570 ; free physical = 757 ; free virtual = 165926
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Start Technology Mapping
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Finished Technology Mapping : Time (s): cpu = 00:00:39 ; elapsed = 00:01:43 . Memory (MB): peak = 2988.160 ; gain = 756.816 ; free physical = 668 ; free virtual = 165857
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Start IO Insertion
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Start Flattening Before IO Insertion
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Finished Flattening Before IO Insertion
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Start Final Netlist Cleanup
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Finished Final Netlist Cleanup
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Finished IO Insertion : Time (s): cpu = 00:00:44 ; elapsed = 00:01:48 . Memory (MB): peak = 2993.086 ; gain = 761.742 ; free physical = 627 ; free virtual = 165856
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Start Renaming Generated Instances
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Finished Renaming Generated Instances : Time (s): cpu = 00:00:44 ; elapsed = 00:01:48 . Memory (MB): peak = 2993.086 ; gain = 761.742 ; free physical = 627 ; free virtual = 165856
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Start Rebuilding User Hierarchy
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Finished Rebuilding User Hierarchy : Time (s): cpu = 00:00:45 ; elapsed = 00:01:50 . Memory (MB): peak = 2993.086 ; gain = 761.742 ; free physical = 622 ; free virtual = 165851
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Start Renaming Generated Ports
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Finished Renaming Generated Ports : Time (s): cpu = 00:00:45 ; elapsed = 00:01:50 . Memory (MB): peak = 2993.086 ; gain = 761.742 ; free physical = 622 ; free virtual = 165851
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Start Handling Custom Attributes
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Finished Handling Custom Attributes : Time (s): cpu = 00:00:45 ; elapsed = 00:01:50 . Memory (MB): peak = 2993.086 ; gain = 761.742 ; free physical = 623 ; free virtual = 165852
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Start Renaming Generated Nets
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Finished Renaming Generated Nets : Time (s): cpu = 00:00:46 ; elapsed = 00:01:50 . Memory (MB): peak = 2993.086 ; gain = 761.742 ; free physical = 622 ; free virtual = 165851
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Start Writing Synthesis Report
# ---------------------------------------------------------------------------------
#
# Report BlackBoxes:
# +-+--------------+----------+
# | |BlackBox name |Instances |
# +-+--------------+----------+
# +-+--------------+----------+
#
# Report Cell Usage:
# +------+-------+------+
# |      |Cell   |Count |
# +------+-------+------+
# |1     |BUFG   |     1|
# |2     |CARRY8 |  2561|
# |3     |LUT1   |  1000|
# |4     |LUT2   | 13803|
# |5     |LUT3   |  8956|
# |6     |LUT4   |  3314|
# |7     |LUT5   |   386|
# |8     |LUT6   |   378|
# |9     |FDRE   | 20372|
# |10    |IBUF   |  7658|
# |11    |OBUF   |    37|
# +------+-------+------+
#
# Report Instance Areas:
# +------+----------------------------------------------------------------------+----------------------------------------------------------+------+
# |      |Instance                                                              |Module                                                    |Cells |
# +------+----------------------------------------------------------------------+----------------------------------------------------------+------+
# |1     |top                                                                   |                                                          | 58466|
# |2     |  grp_dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0_fu_54 |dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0 | 41819|
# +------+----------------------------------------------------------------------+----------------------------------------------------------+------+
# ---------------------------------------------------------------------------------
# Finished Writing Synthesis Report : Time (s): cpu = 00:00:46 ; elapsed = 00:01:50 . Memory (MB): peak = 2993.086 ; gain = 761.742 ; free physical = 622 ; free virtual = 165851
# ---------------------------------------------------------------------------------
# Synthesis finished with 0 errors, 0 critical warnings and 0 warnings.
# Synthesis Optimization Runtime : Time (s): cpu = 00:00:49 ; elapsed = 00:01:54 . Memory (MB): peak = 2996.992 ; gain = 765.648 ; free physical = 6361 ; free virtual = 171595
# Synthesis Optimization Complete : Time (s): cpu = 00:00:49 ; elapsed = 00:01:54 . Memory (MB): peak = 2996.992 ; gain = 765.648 ; free physical = 6384 ; free virtual = 171595
# INFO: [Project 1-571] Translating synthesized netlist
# Netlist sorting complete. Time (s): cpu = 00:00:00.35 ; elapsed = 00:00:00.35 . Memory (MB): peak = 3004.055 ; gain = 0.000 ; free physical = 6337 ; free virtual = 171548
# INFO: [Netlist 29-17] Analyzing 10220 Unisim elements for replacement
# INFO: [Netlist 29-28] Unisim Transformation completed in 0 CPU seconds
# INFO: [Project 1-570] Preparing netlist for logic optimization
# INFO: [Opt 31-138] Pushed 0 inverter(s) to 0 load pin(s).
# Netlist sorting complete. Time (s): cpu = 00:00:00.01 ; elapsed = 00:00:00.01 . Memory (MB): peak = 3202.922 ; gain = 0.000 ; free physical = 6194 ; free virtual = 171420
# INFO: [Project 1-111] Unisim Transformation Summary:
#   A total of 7659 instances were transformed.
#   BUFG => BUFGCE: 1 instance
#   IBUF => IBUF (IBUFCTRL, INBUF): 7658 instances
#
# INFO: [Common 17-83] Releasing license: Synthesis
# 124 Infos, 0 Warnings, 0 Critical Warnings and 0 Errors encountered.
# synth_design completed successfully
# synth_design: Time (s): cpu = 00:01:00 ; elapsed = 00:02:09 . Memory (MB): peak = 3202.922 ; gain = 983.715 ; free physical = 6333 ; free virtual = 171559
# # report_utilization -file vivado_synth.rpt
# INFO: [Common 17-206] Exiting Vivado at Sun Apr 21 16:55:30 2024...
# ***** VIVADO SYNTHESIS COMPLETED IN 0h2m30s *****
# INFO: [HLS 200-112] Total elapsed time: 415.07 seconds; peak allocated memory: 379.689 MB.
# INFO: [Common 17-206] Exiting vivado_hls at Sun Apr 21 16:55:40 2024...
# Cosim report not found.
# Timing report not found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 10
#       2 hls_model.build(
#       3     csim=False,
#       4     synth=True,
#    (...)
#       7     vsynth=True,
#       8 )
#       9 toc = time.time()
# ---> 10 dur = toc - time
#      11 print(f"Duration: {dur//60} minutes, {dur%60} seconds\n")
#
# TypeError: unsupported operand type(s) for -: 'float' and 'module'

# %% [markdown]
# ## Check the report

# %%
hls4ml.report.read_vivado_report(OutputDir)
# Out:
# Found 1 solution(s) in hls4ml_prj/myproject_prj.
# Reports for solution "solution1":
#
# C SIMULATION RESULT:
# INFO: [SIM 2] *************** CSIM start ***************
# INFO: [SIM 4] CSIM will launch GCC as the compiler.
#    Compiling ../../../../myproject_test.cpp in debug mode
#    Compiling ../../../../firmware/myproject.cpp in debug mode
#    Generating csim.exe
# INFO: Unable to open input/predictions file, using default input.
# 1.72363 -1.77441
# INFO: Saved inference results to file: tb_data/csim_results.log
# INFO: [SIM 1] CSim done with 0 errors.
# INFO: [SIM 3] *************** CSIM finish ***************
#
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'myproject'
# ================================================================
# * Date:           Sun Apr 21 16:52:58 2024
#
# * Version:        2020.1.1 (Build 2951007 on Wed Aug 05 23:24:06 MDT 2020)
# * Project:        myproject_prj
# * Solution:       solution1
# * Product family: zynquplus
# * Target device:  xczu49dr-ffvf1760-2-e
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing:
#     * Summary:
#     +--------+---------+----------+------------+
#     |  Clock |  Target | Estimated| Uncertainty|
#     +--------+---------+----------+------------+
#     |ap_clk  | 3.22 ns | 2.558 ns |   0.40 ns  |
#     +--------+---------+----------+------------+
#
# + Latency:
#     * Summary:
#     +---------+---------+-----------+-----------+-----+-----+----------+
#     |  Latency (cycles) |   Latency (absolute)  |  Interval | Pipeline |
#     |   min   |   max   |    min    |    max    | min | max |   Type   |
#     +---------+---------+-----------+-----------+-----+-----+----------+
#     |        4|        4| 12.900 ns | 12.900 ns |    1|    1| function |
#     +---------+---------+-----------+-----------+-----+-----+----------+
#
#     + Detail:
#         * Instance:
#         +------------------------------------------------------------------------------------+--------------------------------------------------------------------+---------+---------+----------+----------+-----+-----+----------+
#         |                                                                                    |                                                                    |  Latency (cycles) |  Latency (absolute) |  Interval | Pipeline |
#         |                                      Instance                                      |                               Module                               |   min   |   max   |    min   |    max   | min | max |   Type   |
#         +------------------------------------------------------------------------------------+--------------------------------------------------------------------+---------+---------+----------+----------+-----+-----+----------+
#         |grp_dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0_fu_54                 |dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0           |        3|        3| 9.675 ns | 9.675 ns |    1|    1| function |
#         |call_ret1_normalize_ap_fixed_18_18_5_3_0_ap_fixed_16_6_5_3_0_config4_0_0_0_0_fu_60  |normalize_ap_fixed_18_18_5_3_0_ap_fixed_16_6_5_3_0_config4_0_0_0_0  |        0|        0|   0 ns   |   0 ns   |    1|    1| function |
#         +------------------------------------------------------------------------------------+--------------------------------------------------------------------+---------+---------+----------+----------+-----+-----+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +-----------------+---------+-------+--------+--------+-----+
# |       Name      | BRAM_18K| DSP48E|   FF   |   LUT  | URAM|
# +-----------------+---------+-------+--------+--------+-----+
# |DSP              |        -|      -|       -|       -|    -|
# |Expression       |        -|      -|       0|       6|    -|
# |FIFO             |        -|      -|       -|       -|    -|
# |Instance         |        -|     28|   26619|   27955|    -|
# |Memory           |        -|      -|       -|       -|    -|
# |Multiplexer      |        -|      -|       -|      36|    -|
# |Register         |        -|      -|   21566|       -|    -|
# +-----------------+---------+-------+--------+--------+-----+
# |Total            |        0|     28|   48185|   27997|    0|
# +-----------------+---------+-------+--------+--------+-----+
# |Available        |     2160|   4272|  850560|  425280|   80|
# +-----------------+---------+-------+--------+--------+-----+
# |Utilization (%)  |        0|   ~0  |       5|       6|    0|
# +-----------------+---------+-------+--------+--------+-----+
#
# + Detail:
#     * Instance:
#     +------------------------------------------------------------------------------------+--------------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |                                      Instance                                      |                               Module                               | BRAM_18K| DSP48E|   FF  |  LUT  | URAM|
#     +------------------------------------------------------------------------------------+--------------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |grp_dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0_fu_54                 |dense_latency_ap_fixed_ap_fixed_18_18_5_3_0_config2_0_0_0           |        0|     28|  26619|  27863|    0|
#     |call_ret1_normalize_ap_fixed_18_18_5_3_0_ap_fixed_16_6_5_3_0_config4_0_0_0_0_fu_60  |normalize_ap_fixed_18_18_5_3_0_ap_fixed_16_6_5_3_0_config4_0_0_0_0  |        0|      0|      0|     92|    0|
#     +------------------------------------------------------------------------------------+--------------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |Total                                                                               |                                                                    |        0|     28|  26619|  27955|    0|
#     +------------------------------------------------------------------------------------+--------------------------------------------------------------------+---------+-------+-------+-------+-----+
#
# Co-simulation report not found.
